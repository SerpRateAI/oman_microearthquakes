# %% [markdown]
# # Compare the geophone data with the sensitivity and response removed

# %%
# Import modules
from obspy import read

# %%
# Inputs
inpath_sens = "/Volumes/OmanData/data/geophones_new/2020-01-10-04/7F.A10..mseed"

# inpath_resp_1 = "/Volumes/OmanData/data/geophones/2020-01-16-00-00-00/7F.A01.2020-01-16-00-00-00..GH1.SAC"
# inpath_resp_2 = "/Volumes/OmanData/data/geophones/2020-01-16-00-00-00/7F.A01.2020-01-16-00-00-00..GH2.SAC"
# inpath_resp_Z = "/Volumes/OmanData/data/geophones/2020-01-16-00-00-00/7F.A01.2020-01-16-00-00-00..GHZ.SAC"

# %%
# Read in data
stream_sens = read(inpath_sens)

# stream_resp_1 = read(inpath_resp_1)
# stream_resp_2 = read(inpath_resp_2)
# stream_resp_Z = read(inpath_resp_Z)

# stream_resp = stream_resp_1 + stream_resp_2 + stream_resp_Z

# %%
# Plot the data
stream_sens.plot()

# stream_resp.filter("highpass", freq=5)
# stream_resp.plot()
