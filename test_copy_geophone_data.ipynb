# %% [markdown]
# # Test copying the hydrophone data from Rob's disk to my local disk

# %%
from os.path import join, exists, basename
from os import makedirs
from obspy import read, read_inventory, Stream
from glob import glob
from numpy import amax
from matplotlib.pyplot import figure, subplots
from pandas import to_datetime
from sys import getsizeof

from utils_basic import ROOTDIR_HYDRO, METAPATH_HYDRO, HYDRO_STATIONS, HYDRO_LOCATIONS, NETWORK

# %%
inpath_geo = "/Volumes/Oman4/PASSCAL/Main_deployment/DAYS/A02/A02.7F..GH1.2020.025"

# %%
stream_geo = read(inpath_geo)
print(stream_geo)

stream_geo.plot()
# Out:
# 1 Trace(s) in Stream:
# 7F.A02..BH1 | 2020-01-25T00:00:00.000000Z - 2020-01-25T23:59:59.999000Z | 1000.0 Hz, 86400000 samples
