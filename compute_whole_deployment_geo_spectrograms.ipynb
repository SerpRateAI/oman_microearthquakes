# %% [markdown]
# # Compute the whole deployment geophone spectrograms for a list of stations
# The results for each station is stored in a single HDF5 file, with the spectrograms for each day saved in a separate block for easy reading and writing

# %%
# Imports
from os import makedirs
from os.path import join
from time import time

from utils_basic import SPECTROGRAM_DIR as outdir, GEO_STATIONS as stations
from utils_basic import day2suffix, get_geophone_days, get_geo_metadata
from utils_preproc import read_and_process_day_long_geo_waveforms
from utils_spec import assemble_spec_filename, create_geo_spectrogram_file, write_geo_spectrogram_block, finish_geo_spectrogram_file
from utils_torch import get_daily_geo_spectrograms

# %%
# Inputs
block_type = "daily"
window_length = 1.0 # IN SECONDS
overlap = 0.0
downsample = False # Downsample along the frequency axis
downsample_factor = 60 # Downsample factor for the frequency axis
resample_in_parallel = True # Resample along the time axis in parallel
num_process_resample = 8 # Number of processes while resampling along the time axis in parallel
save_ds_only = False # Whether to save only the downsampled spectrograms

if not downsample and save_ds_only:
    raise ValueError("Conflicting options for downsampling!")

# %%
# Create the output directory
makedirs(outdir, exist_ok=True)

# %%
# Load the station metadata
metadata = get_geo_metadata()

# %%
# Get the geophone deployment days
days = get_geophone_days()
# days = ["2020-01-13"]

# %%
# Compute the frequency intervals
freq_interval = 1.0 / window_length
freq_interval_ds = freq_interval * downsample_factor

# Loop over stations
for station in stations:
    print("######")
    print(f"Processing {station}...")
    print("######")
    print("")
    
    # Create the HDF5 files
    if not save_ds_only:
        file = create_geo_spectrogram_file(station, 
                                           window_length = window_length, overlap = overlap, 
                                           block_type = block_type, freq_interval = freq_interval, downsample = False, outdir = outdir)

    if downsample:
        file_ds = create_geo_spectrogram_file(station, 
                                              window_length = window_length, overlap = overlap,
                                              block_type = block_type, freq_interval = freq_interval_ds, downsample = True, downsample_factor = downsample_factor, outdir = outdir)

    # Loop over days
    num_days = len(days)
    time_labels = []
    for i, day in enumerate(days):
        # Start the clock
        clock1 = time()
        print(f"### Processing {day} for {station}... ###")

        # Read and preprocess the data
        stream_day = read_and_process_day_long_geo_waveforms(day, metadata, stations = station)
        if stream_day is None:
            print(f"{day} is skipped.")
            continue

        # Compute the spectrogram
        stream_spec, stream_spec_ds = get_daily_geo_spectrograms(stream_day, 
                                                                 window_length = window_length, overlap = overlap,
                                                                 resample_in_parallel = resample_in_parallel, num_process_resample = num_process_resample,
                                                                 downsample = downsample, downsample_factor = downsample_factor)
        time_labels.append(stream_spec[0].time_label)
        
        # Write the spectrogram block
        if not save_ds_only:
            write_geo_spectrogram_block(file, stream_spec, close_file = False)

        if downsample:
            write_geo_spectrogram_block(file_ds, stream_spec_ds, close_file = False)

        # Stop the clock
        clock2 = time()
        elapse = clock2 - clock1
        
        print(f"Elapsed time: {elapse} s")

    # Finish the spectrogram file
    if not save_ds_only:
        finish_geo_spectrogram_file(file, time_labels)
    if downsample:
        finish_geo_spectrogram_file(file_ds, time_labels)
        
    print("")
# Out:
# ######
# Processing A01...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A01_window1s_overlap0.0.h5
# ### Processing 2020-01-10 for A01... ###
# Reading the waveforms for 2020-01-10
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200110000000000000 is saved
# Elapsed time: 7.6550328731536865 s
# ### Processing 2020-01-11 for A01... ###
# Reading the waveforms for 2020-01-11
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200111000000000000 is saved
# Elapsed time: 10.007359743118286 s
# ### Processing 2020-01-12 for A01... ###
# Reading the waveforms for 2020-01-12
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200112000000000000 is saved
# Elapsed time: 10.06876277923584 s
# ### Processing 2020-01-13 for A01... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 10.274324893951416 s
# ### Processing 2020-01-14 for A01... ###
# Reading the waveforms for 2020-01-14
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200114000000000000 is saved
# Elapsed time: 9.988092184066772 s
# ### Processing 2020-01-15 for A01... ###
# Reading the waveforms for 2020-01-15
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200115000000000000 is saved
# Elapsed time: 10
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200114000000000000 is saved
# Elapsed time: 10.130198955535889 s
# ### Processing 2020-01-15 for B20... ###
# Reading the waveforms for 2020-01-15
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200115000000000000 is saved
# Elapsed time: 10.494904518127441 s
# ### Processing 2020-01-16 for B20... ###
# Reading the waveforms for 2020-01-16
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200116000000000000 is saved
# Elapsed time: 10.319095373153687 s
# ### Processing 2020-01-17 for B20... ###
# Reading the waveforms for 2020-01-17
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200117000000000000 is saved
# Elapsed time: 10.195052146911621 s
# ### Processing 2020-01-18 for B20... ###
# Reading the waveforms for 2020-01-18
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200118000000000000 is saved
# Elapsed time: 10.512067794799805 s
# ### Processing 2020-01-19 for B20... ###
# Reading the waveforms for 2020-01-19
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200119000000000000 is saved
# Elapsed time: 10.942574262619019 s
# ### Processing 2020-01-20 for B20... ###
# Reading the waveforms for 2020-01-20
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200120000000000000 is saved
# Elapsed time: 10.735620021820068 s
# ### Processing 2020-01-21 for B20... ###
# Reading the waveforms for 2020-01-21
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200121000000000000 is saved
# Elapsed time: 10.620221376419067 s
# ### Processing 2020-01-22 for B20... ###
# Reading the waveforms for 2020-01-22
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200122000000000000 is saved
# Elapsed time: 10.611630916595459 s
# ### Processing 2020-01-23 for B20... ###
# Reading the waveforms for 2020-01-23
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200123000000000000 is saved
# Elapsed time: 10.51209568977356 s
# ### Processing 2020-01-24 for B20... ###
# Reading the waveforms for 2020-01-24
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200124000000000000 is saved
# Elapsed time: 10.570155382156372 s
# ### Processing 2020-01-25 for B20... ###
# Reading the waveforms for 2020-01-25
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200125000000000000 is saved
# Elapsed time: 10.73845100402832 s
# ### Processing 2020-01-26 for B20... ###
# Reading the waveforms for 2020-01-26
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200126000000000000 is saved
# Elapsed time: 11.076940059661865 s
# ### Processing 2020-01-27 for B20... ###
# Reading the waveforms for 2020-01-27
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200127000000000000 is saved
# Elapsed time: 10.974407434463501 s
# ### Processing 2020-01-28 for B20... ###
# Reading the waveforms for 2020-01-28
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200128000000000000 is saved
# Elapsed time: 10.729613304138184 s
# ### Processing 2020-01-29 for B20... ###
# Reading the waveforms for 2020-01-29
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200129000000000000 is saved
# Elapsed time: 10.736487865447998 s
# ### Processing 2020-01-30 for B20... ###
# Reading the waveforms for 2020-01-30
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200130000000000000 is saved
# Elapsed time: 10.991643905639648 s
# ### Processing 2020-01-31 for B20... ###
# Reading the waveforms for 2020-01-31
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200131000000000000 is saved
# Elapsed time: 10.614991903305054 s
# ### Processing 2020-02-01 for B20... ###
# Reading the waveforms for 2020-02-01
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200201000000000000 is saved
# Elapsed time: 10.657241582870483 s
# ### Processing 2020-02-02 for B20... ###
# Reading the waveforms for 2020-02-02
# Preprocessing the waveforms...
# Computing the spectrograms...
# Resampling the spectrograms to the begin and end of the day...
# Spectrogram block 20200202000000000000 is saved
# Elapsed time: 5.85299277305603 s
# ### Processing 2020-02-03 for B20... ###
# Reading the waveforms for 2020-02-03
# An error occurred: No file matching file pattern: /fp/projects01/ec332/data/geophones/2020-02-03/7F.B20*GHZ.mseed
# Warning: No data found for B20.GHZ!
# Warning: Not all components read for B20! The station is skipped.
# Preprocessing the waveforms...
# 2020-02-03 is skipped.
# Time labels are saved.
# The spectrogram file is closed.
