# %% [markdown]
# # Compute the whole deployment geophone spectrograms for a list of stations
# The results for each station is stored in a single HDF5 file, with the spectrograms for each day saved in a separate block for easy reading and writing

# %%
# Imports
from os import makedirs
from os.path import join
from time import time

from utils_basic import SPECTROGRAM_DIR as outdir, GEO_STATIONS as stations
from utils_basic import day2suffix, get_geophone_days, get_geo_metadata
from utils_preproc import read_and_process_day_long_geo_waveforms
from utils_spec import assemble_spec_filename, create_geo_spectrogram_file, write_geo_spectrogram_block, finish_geo_spectrogram_file
from utils_torch import get_daily_geo_spectrograms

# %%
# Inputs
block_type = "daily"
window_length = 1.0 # IN SECONDS
overlap = 0.0
downsample = False
downsample_factor = 1 # Downsample factor for the frequency axis
save_ds_only = False # Wheter to save only the downsampled spectrograms

if not downsample and save_ds_only:
    raise ValueError("Conflicting options for downsampling!")

# %%
# Create the output directory
makedirs(outdir, exist_ok=True)

# %%
# Load the station metadata
metadata = get_geo_metadata()

# %%
# Get the geophone deployment days
#days = get_geophone_days()
days = ["2020-01-13"]

# %%
# Compute the frequency intervals
freq_interval = 1.0 / window_length
freq_interval_ds = freq_interval * downsample_factor

# Loop over stations
for station in stations:
    print("######")
    print(f"Processing {station}...")
    print("######")
    print("")
    
    # Create the HDF5 files
    if not save_ds_only:
        file = create_geo_spectrogram_file(station, 
                                           window_length = window_length, overlap = overlap, 
                                           block_type = block_type, freq_interval = freq_interval, downsample = False, outdir = outdir)

    if downsample:
        file_ds = create_geo_spectrogram_file(station, 
                                              window_length = window_length, overlap = overlap,
                                              block_type = block_type, freq_interval = freq_interval_ds, downsample = True, downsample_factor = downsample_factor, outdir = outdir)

    # Loop over days
    num_days = len(days)
    time_labels = []
    for i, day in enumerate(days):
        # Start the clock
        clock1 = time()
        print(f"### Processing {day} for {station}... ###")

        # Read and preprocess the data
        stream_day = read_and_process_day_long_geo_waveforms(day, metadata, stations = station)
        if stream_day is None:
            print(f"{day} is skipped.")
            continue

        # Compute the spectrogram
        stream_spec, stream_spec_ds = get_daily_geo_spectrograms(stream_day, window_length = window_length, overlap = overlap, downsample = downsample, downsample_factor = downsample_factor)
        time_labels.append(stream_spec[0].time_label)
        
        # Write the spectrogram block
        if not save_ds_only:
            write_geo_spectrogram_block(file, stream_spec, close_file = False)

        if downsample:
            write_geo_spectrogram_block(file_ds, stream_spec_ds, close_file = False)

        # Stop the clock
        clock2 = time()
        elapse = clock2 - clock1
        
        print(f"Elapsed time: {elapse} s")

    # Finish the spectrogram file
    if not save_ds_only:
        finish_geo_spectrogram_file(file, time_labels)
    if downsample:
        finish_geo_spectrogram_file(file_ds, time_labels)
        
    print("")
# Out:
# ######
# Processing A01...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A01_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A01... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.789902448654175 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A02...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A02_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A02... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.206691265106201 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A03...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A03_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A03... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.168462038040161 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A04...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A04_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A04... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.260459899902344 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A05...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A05_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A05... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.320201635360718 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A06...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A06_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A06... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.139479398727417 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A07...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A07_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A07... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.205296754837036 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A08...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A08_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A08... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.627861738204956 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A09...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A09_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A09... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.3380820751190186 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A10...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A10_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A10... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.177988767623901 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A11...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A11_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A11... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.143700838088989 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A13...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A13_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A13... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.312309265136719 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A14...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A14_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A14... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.270752191543579 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A15...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A15_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A15... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.357216835021973 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A16...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A16_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A16... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.254540205001831 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A17...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A17_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A17... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.161949872970581 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing A19...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_A19_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for A19... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.203007459640503 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B01...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B01_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B01... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.137204170227051 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B02...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B02_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B02... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.218533992767334 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B03...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B03_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B03... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.172379016876221 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B04...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B04_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B04... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.180748701095581 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B06...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B06_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B06... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.064678192138672 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B07...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B07_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B07... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.268544435501099 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B08...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B08_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B08... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.354155778884888 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B09...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B09_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B09... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.05019211769104 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B10...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B10_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B10... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.223734378814697 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B11...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B11_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B11... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.466929912567139 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B12...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B12_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B12... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.3777241706848145 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B13...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B13_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B13... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.384013414382935 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B14...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B14_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B14... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.4493303298950195 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B15...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B15_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B15... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.235298156738281 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B16...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B16_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B16... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.130100727081299 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B17...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B17_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B17... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.353148937225342 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B18...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B18_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B18... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.4323813915252686 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B19...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B19_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B19... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.270870208740234 s
# Time labels are saved.
# The spectrogram file is closed.
#
# ######
# Processing B20...
# ######
#
# Created spectrogram file /fp/projects01/ec332/data/spectrograms/whole_deployment_daily_geo_spectrograms_B20_window1s_overlap0.0.h5
# ### Processing 2020-01-13 for B20... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Spectrogram block 20200113000000000000 is saved
# Elapsed time: 6.13262939453125 s
# Time labels are saved.
# The spectrogram file is closed.
