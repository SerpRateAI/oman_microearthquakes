# %% [markdown]
# # Stack the geophone spectrograms of all geophone stations and find the spectral peaks in the stacked spectrogram

# %%
# Imports
from os.path import join
from pandas import concat, Timestamp
from time import time
from multiprocessing import Pool

from utils_basic import SPECTROGRAM_DIR as indir, GEO_STATIONS as stations
from utils_basic import get_geophone_days
from utils_spec import find_trace_spectral_peaks, get_spectrogram_file_suffix, get_spec_peak_file_suffix 
from utils_spec import read_geo_spectrograms, read_geo_spec_headers, save_spectral_peaks
from utils_plot import plot_geo_total_psd_and_peaks, save_figure

# %%
# Inputs
# Data
window_length = 1.0
overlap = 0.0
downsample = False
downsample_factor = 60

# Finding peaks
num_process = 32
rbw_threshold = 0.2
prom_threshold = 10
min_freq = None
max_freq = 200.0

# Writing
to_csv = False
to_hdf = True

# %%
# Get the time labels to process
days = get_geophone_days()
time_labels = [Timestamp(day).strftime("%Y%m%d%H%M%S%f") for day in days]

# %%
# Compute the stack and find the peaks for each time label
suffix_spec = get_spectrogram_file_suffix(window_length, overlap, downsample, downsample_factor = downsample_factor)
peak_dfs = []
for time_label in time_labels:
    print(f"Processing {time_label}...")
    clock1 = time()

    # Loop over stations to compute the stack
    num_sta = 0
    for i, station in enumerate(stations):
        print(f"Processing {station}...")
        

        # Read the spectrogram blocks
        filename = f"whole_deployment_daily_geo_spectrograms_{station}_{suffix_spec}.h5"
        inpath = join(indir, filename)
        stream_spec = read_geo_spectrograms(inpath, time_labels = [time_label])

        if stream_spec is None:
            print(f"No data for {station} at {time_label}.")
            continue
        else:
            num_sta += 1

        # Compute the total PSD
        trace_spec_total = stream_spec.get_total_power()

        # Stack the PSDs
        if num_sta == 1:
            trace_spec_stack = trace_spec_total.copy()
        else:
            trace_spec_stack.data += trace_spec_total.data

    if num_sta == 0:
        print(f"No data for any station at {time_label}.")
        continue

    # Divide by the number of stations
    trace_spec_stack.data /= num_sta

    # Find the spectral peaks
    peak_df = find_trace_spectral_peaks(trace_spec_stack, num_process, prom_threshold = prom_threshold, rbw_threshold = rbw_threshold, min_freq = min_freq, max_freq = max_freq)
    num_peaks = len(peak_df)
    print(f"Found {num_peaks} peaks.")

    clock2 = time()
    print(f"Elapsed time: {clock2 - clock1} s.")

    # Append to the list
    peak_dfs.append(peak_df)
    
print("Done.")
print("")

# Concatenate the peak dataframes
print("Concatenating the peak dataframes...")
if len(peak_dfs) > 0:
    peak_df = concat(peak_dfs, axis = 0)

num_peaks = len(peak_df)
print(f"Total number of peaks: {num_peaks}.")
# Out:
# Processing 20200110000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 66258 peaks.
# Elapsed time: 30.54726505279541 s.
# Processing 20200111000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 147110 peaks.
# Elapsed time: 77.784250497818 s.
# Processing 20200112000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 136132 peaks.
# Elapsed time: 28.58631157875061 s.
# Processing 20200113000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 136454 peaks.
# Elapsed time: 52.79751682281494 s.
# Processing 20200114000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 145351 peaks.
# Elapsed time: 39.57407760620117 s.
# Processing 20200115000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 126252 peaks.
# Elapsed time: 30.092317581176758 s.
# Processing 20200116000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 121729 peaks.
# Elapsed time: 21.68214702606201 s.
# Processing 20200117000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 125148 peaks.
# Elapsed time: 47.1311411857605 s.
# Processing 20200118000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 125838 peaks.
# Elapsed time: 31.6870334148407 s.
# Processing 20200119000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 127841 peaks.
# Elapsed time: 74.41148519515991 s.
# Processing 20200120000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 153252 peaks.
# Elapsed time: 23.68826913833618 s.
# Processing 20200121000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 143039 peaks.
# Elapsed time: 31.043938159942627 s.
# Processing 20200122000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 120076 peaks.
# Elapsed time: 37.80784463882446 s.
# Processing 20200123000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 136098 peaks.
# Elapsed time: 38.95536994934082 s.
# Processing 20200124000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 144752 peaks.
# Elapsed time: 21.63289523124695 s.
# Processing 20200125000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 126528 peaks.
# Elapsed time: 23.769200325012207 s.
# Processing 20200126000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 128104 peaks.
# Elapsed time: 34.32951498031616 s.
# Processing 20200127000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 185870 peaks.
# Elapsed time: 28.401161193847656 s.
# Processing 20200128000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 208167 peaks.
# Elapsed time: 22.207929372787476 s.
# Processing 20200129000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 219277 peaks.
# Elapsed time: 22.573725938796997 s.
# Processing 20200130000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 242894 peaks.
# Elapsed time: 45.7777214050293 s.
# Processing 20200131000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 206376 peaks.
# Elapsed time: 36.34062194824219 s.
# Processing 20200201000000000000...
# Processing A01...
# Processing A02...
# Processing A03...
# Processing A04...
# Processing A05...
# Processing A06...
# Processing A07...
# Processing A08...
# Processing A09...
# Processing A10...
# Processing A11...
# Processing A13...
# Processing A14...
# Processing A15...
# Processing A16...
# Processing A17...
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 54663 peaks.
# Elapsed time: 64.31914973258972 s.
# Processing 20200202000000000000...
# Processing A01...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A01 at 20200202000000000000.
# Processing A02...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A02 at 20200202000000000000.
# Processing A03...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A03 at 20200202000000000000.
# Processing A04...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A04 at 20200202000000000000.
# Processing A05...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A05 at 20200202000000000000.
# Processing A06...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A06 at 20200202000000000000.
# Processing A07...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A07 at 20200202000000000000.
# Processing A08...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A08 at 20200202000000000000.
# Processing A09...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A09 at 20200202000000000000.
# Processing A10...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A10 at 20200202000000000000.
# Processing A11...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A11 at 20200202000000000000.
# Processing A13...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A13 at 20200202000000000000.
# Processing A14...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A14 at 20200202000000000000.
# Processing A15...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A15 at 20200202000000000000.
# Processing A16...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A16 at 20200202000000000000.
# Processing A17...
# Warning: Time label 20200202000000000000 does not exist!
# No data for A17 at 20200202000000000000.
# Processing A19...
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Processing B14...
# Processing B15...
# Processing B16...
# Processing B17...
# Processing B18...
# Processing B19...
# Processing B20...
# Finding the spectral peaks in 32 processes...
# Found 40995 peaks.
# Elapsed time: 26.941174745559692 s.
# Processing 20200203000000000000...
# Processing A01...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A01 at 20200203000000000000.
# Processing A02...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A02 at 20200203000000000000.
# Processing A03...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A03 at 20200203000000000000.
# Processing A04...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A04 at 20200203000000000000.
# Processing A05...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A05 at 20200203000000000000.
# Processing A06...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A06 at 20200203000000000000.
# Processing A07...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A07 at 20200203000000000000.
# Processing A08...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A08 at 20200203000000000000.
# Processing A09...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A09 at 20200203000000000000.
# Processing A10...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A10 at 20200203000000000000.
# Processing A11...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A11 at 20200203000000000000.
# Processing A13...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A13 at 20200203000000000000.
# Processing A14...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A14 at 20200203000000000000.
# Processing A15...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A15 at 20200203000000000000.
# Processing A16...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A16 at 20200203000000000000.
# Processing A17...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A17 at 20200203000000000000.
# Processing A19...
# Warning: Time label 20200203000000000000 does not exist!
# No data for A19 at 20200203000000000000.
# Processing B01...
# Processing B02...
# Processing B03...
# Processing B04...
# Processing B06...
# Processing B07...
# Processing B08...
# Processing B09...
# Processing B10...
# Processing B11...
# Processing B12...
# Processing B13...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B13 at 20200203000000000000.
# Processing B14...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B14 at 20200203000000000000.
# Processing B15...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B15 at 20200203000000000000.
# Processing B16...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B16 at 20200203000000000000.
# Processing B17...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B17 at 20200203000000000000.
# Processing B18...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B18 at 20200203000000000000.
# Processing B19...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B19 at 20200203000000000000.
# Processing B20...
# Warning: Time label 20200203000000000000 does not exist!
# No data for B20 at 20200203000000000000.
# Finding the spectral peaks in 32 processes...
# Found 34614 peaks.
# Elapsed time: 8.13643217086792 s.
# Done.
#
# Concatenating the peak dataframes...
# Total number of peaks: 3402818.

# %%
# Save the peaks
suffix_peak = get_spec_peak_file_suffix(prom_threshold, rbw_threshold, min_freq = min_freq, max_freq = max_freq)
file_stem = f"geo_stack_spectral_peaks_{suffix_spec}_{suffix_peak}"

if to_csv:
    save_spectral_peaks(peak_df, file_stem, "csv")

if to_hdf:
    save_spectral_peaks(peak_df, file_stem, "h5")
# Out:
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_stack_spectral_peaks_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
