# %% [markdown]
# # Compute daily geophone spectrograms using STFT

# %%
# Imports
from os import makedirs
from os.path import join
from time import time

from utils_basic import SPECTROGRAM_DIR as outdir, GEO_STATIONS as stations
from utils_basic import day2suffix, get_geo_metadata
from utils_preproc import read_and_process_day_long_geo_waveforms
from utils_spec import assemble_spec_filename, save_geo_spectrograms
from utils_torch import get_daily_geo_spectrograms

# %%
# Inputs
days = ["2020-01-13"]

window_length = 60.0 # IN SECONDS
overlap = 0.0
downsample_factor = 60 # Downsample factor for the frequency axis
save_ds_only = True # Wheter to save only the downsampled spectrograms

outdir = join(outdir, "daily")

# %%
# Create the output directory
makedirs(outdir, exist_ok=True)

# %%
# Load the station metadata
metadata = get_geo_metadata()

# %%
# Loop over days:
for day in days:
    for station in stations:
        # Start the clock
        clock1 = time()
        print(f"### Processing {day} for {station}... ###")

        # Read and preprocess the data
        stream_day = read_and_process_day_long_geo_waveforms(day, metadata, stations = station)

        # Compute the spectrogram
        stream_spec, stream_spec_ds = get_daily_geo_spectrograms(stream_day, window_length = window_length, overlap = overlap, downsample = True, downsample_factor = downsample_factor)

        # Save the spectrogram
        print("Saving the spectrograms...")
        day_suffix = day2suffix(day)
        
        if not save_ds_only:
            assemble_spec_filename("daily", "geo", day_suffix, station, window_length, overlap, False)
            save_geo_spectrograms(stream_spec, filename, outdir = outdir)
            
        filename = assemble_spec_filename("daily", "geo", day_suffix, station, window_length, overlap, True, downsample_factor = downsample_factor)
        save_geo_spectrograms(stream_spec_ds, filename, outdir = outdir)

        # Stop the clock
        clock2 = time()
        elapse = clock2 - clock1
        
        print(f"Elapsed time: {elapse} s")
# Out:
# ### Processing 2020-01-13 for A01... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A01_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.175439834594727 s
# ### Processing 2020-01-13 for A02... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A02_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.309199094772339 s
# ### Processing 2020-01-13 for A03... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A03_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.184996843338013 s
# ### Processing 2020-01-13 for A04... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A04_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.184982776641846 s
# ### Processing 2020-01-13 for A05... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A05_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.233082294464111 s
# ### Processing 2020-01-13 for A06... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A06_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.199729681015015 s
# ### Processing 2020-01-13 for A07... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A07_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.039718151092529 s
# ### Processing 2020-01-13 for A08... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A08_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.301045656204224 s
# ### Processing 2020-01-13 for A09... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A09_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.027318716049194 s
# ### Processing 2020-01-13 for A10... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A10_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.278855562210083 s
# ### Processing 2020-01-13 for A11... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A11_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.216379165649414 s
# ### Processing 2020-01-13 for A13... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A13_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.204178333282471 s
# ### Processing 2020-01-13 for A14... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A14_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.091866731643677 s
# ### Processing 2020-01-13 for A15... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A15_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.194418907165527 s
# ### Processing 2020-01-13 for A16... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A16_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.363363981246948 s
# ### Processing 2020-01-13 for A17... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A17_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.28842306137085 s
# ### Processing 2020-01-13 for A19... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_A19_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.201634883880615 s
# ### Processing 2020-01-13 for B01... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B01_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.227887153625488 s
# ### Processing 2020-01-13 for B02... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B02_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.227627515792847 s
# ### Processing 2020-01-13 for B03... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B03_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.2425150871276855 s
# ### Processing 2020-01-13 for B04... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B04_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.18596887588501 s
# ### Processing 2020-01-13 for B06... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B06_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.3076863288879395 s
# ### Processing 2020-01-13 for B07... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B07_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.304214954376221 s
# ### Processing 2020-01-13 for B08... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B08_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.038980007171631 s
# ### Processing 2020-01-13 for B09... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B09_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.043044328689575 s
# ### Processing 2020-01-13 for B10... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B10_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.016554832458496 s
# ### Processing 2020-01-13 for B11... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B11_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.349792718887329 s
# ### Processing 2020-01-13 for B12... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B12_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.351908922195435 s
# ### Processing 2020-01-13 for B13... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B13_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.026756763458252 s
# ### Processing 2020-01-13 for B14... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B14_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.041641712188721 s
# ### Processing 2020-01-13 for B15... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B15_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.066767930984497 s
# ### Processing 2020-01-13 for B16... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B16_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.198862552642822 s
# ### Processing 2020-01-13 for B17... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B17_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.2544262409210205 s
# ### Processing 2020-01-13 for B18... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B18_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.210265874862671 s
# ### Processing 2020-01-13 for B19... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B19_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.228036403656006 s
# ### Processing 2020-01-13 for B20... ###
# Reading the waveforms for 2020-01-13
# Preprocessing the waveforms...
# Computing the spectrograms...
# Trimming the spectrograms to the begin and end of the day...
# Downsampling the spectrograms...
# Saving the spectrograms...
# Spectrograms saved to /fp/projects01/ec332/data/spectrograms/daily/daily_geo_spectrograms_20200113_B20_window60s_overlap0.0_downsample60.h5
# Elapsed time: 5.290517807006836 s
