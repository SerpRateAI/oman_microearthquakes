# %% [markdown]
# # Find spectral peaks in geophone spectrograms

# %%
# Imports
from os.path import join
from pandas import concat
from time import time
from multiprocessing import Pool

from utils_basic import SPECTROGRAM_DIR as indir, GEO_STATIONS as stations
from utils_spec import find_geo_station_spectral_peaks, get_spectrogram_file_suffix, get_spec_peak_file_suffix 
from utils_spec import read_geo_spectrograms, read_geo_spec_headers, save_spectral_peaks
from utils_plot import plot_geo_total_psd_and_peaks, save_figure

# %%
# Inputs
# Data
window_length = 1.0
overlap = 0.0
downsample = False
downsample_factor = 60

# Finding peaks
num_process = 32
rbw_threshold = 0.2
prom_threshold = 10
min_freq = None
max_freq = 200.0

# Writing
to_csv = False
to_hdf = True

# %%
# Loop over days and stations
outdir = indir
for station in stations:
    print(f"### Working on {station}... ###")

    # The DataFrame for storing the peak detections for the stations
    peak_dfs = []

    # Read the list of time labels
    print("Reading the list of time labels...")
    suffix_spec = get_spectrogram_file_suffix(window_length, overlap, downsample, downsample_factor = downsample_factor)
    filename_in = f"whole_deployment_daily_geo_spectrograms_{station}_{suffix_spec}.h5"
    inpath = join(indir, filename_in)

    header_dict = read_geo_spec_headers(inpath)
    time_labels = header_dict["time_labels"]

    # Process each time label
    for time_label in time_labels:
        clock1 = time()
        # Read the spectrograms
        print(f"Reading the spectrograms of {time_label}...")
        stream_spec = read_geo_spectrograms(inpath, time_labels = [time_label])

        # Find the peaks
        print("Detecting the peaks...")
        peak_df, _ = find_geo_station_spectral_peaks(stream_spec, num_process, 
                                                     rbw_threshold = rbw_threshold, prom_threshold = prom_threshold, 
                                                     min_freq = min_freq, max_freq = max_freq)
        print(f"In total, {len(peak_df)} spectral peaks found.")

        # Add the station to the dataframe
        peak_df["station"] = station

        # Append to the list
        peak_dfs.append(peak_df)

        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")

    # Save the results
    print("Saving the results...")
    peak_df = concat(peak_dfs)
    peak_df.drop_duplicates(subset = ["station", "time", "frequency"], inplace = True)
    peak_df.reset_index(drop = True, inplace = True)

    suffix_peak = get_spec_peak_file_suffix(prom_threshold, rbw_threshold, min_freq = min_freq, max_freq = max_freq)
    file_stem = f"geo_spectral_peaks_{station}_{suffix_spec}_{suffix_peak}"

    if to_csv:
        print("Saving the CSV file...")
        clock1 = time()

        save_spectral_peaks(peak_df, file_stem, "csv")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")

    
    if to_hdf:
        print("Saving the HDF file...")
        clock1 = time()
    
        save_spectral_peaks(peak_df, file_stem, "hdf")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")
# Out:
# ### Working on A01... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 352003 spectral peaks found.
# Elapsed time: 2.1114301681518555
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 510519 spectral peaks found.
# Elapsed time: 2.293147325515747
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422596 spectral peaks found.
# Elapsed time: 2.1965057849884033
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 451023 spectral peaks found.
# Elapsed time: 1.9933860301971436
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 457930 spectral peaks found.
# Elapsed time: 2.3076136112213135
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422246 spectral peaks found.
# Elapsed time: 2.2404890060424805
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 414140 spectral peaks found.
# Elapsed time: 2.0532431602478027
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 431532 spectral peaks found.
# Elapsed time: 2.201068162918091
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450604 spectral peaks found.
# Elapsed time: 2.136110782623291
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455354 spectral peaks found.
# Elapsed time: 2.2351248264312744
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 476286 spectral peaks found.
# Elapsed time: 2.185718059539795
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 468133 spectral peaks found.
# Elapsed time: 2.36320424079895
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 429600 spectral peaks found.
# Elapsed time: 2.415832996368408
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 136608 spectral peaks found.
# Elapsed time: 1.7594778537750244
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A05_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6355621814727783
#
# ### Working on A06... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 305293 spectral peaks found.
# Elapsed time: 2.1468422412872314
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 465062 spectral peaks found.
# Elapsed time: 2.3928089141845703
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 425742 spectral peaks found.
# Elapsed time: 2.339216947555542
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 443274 spectral peaks found.
# Elapsed time: 2.1193807125091553
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450308 spectral peaks found.
# Elapsed time: 2.3412418365478516
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422905 spectral peaks found.
# Elapsed time: 2.2854056358337402
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 424481 spectral peaks found.
# Elapsed time: 2.0820090770721436
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 436608 spectral peaks found.
# Elapsed time: 2.2993083000183105
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 449702 spectral peaks found.
# Elapsed time: 2.054760456085205
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455228 spectral peaks found.
# Elapsed time: 2.1707441806793213
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 474923 spectral peaks found.
# Elapsed time: 2.3319010734558105
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 465420 spectral peaks found.
# Elapsed time: 2.2631516456604004
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 480867 spectral peaks found.
# Elapsed time: 2.4246745109558105
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 481524 spectral peaks found.
# Elapsed time: 2.353527784347534
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 483983 spectral peaks found.
# Elapsed time: 2.146610736846924
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 474373 spectral peaks found.
# Elapsed time: 2.37026309967041
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 428136 spectral peaks found.
# Elapsed time: 2.177182912826538
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 425061 spectral peaks found.
# Elapsed time: 2.3297526836395264
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 440782 spectral peaks found.
# Elapsed time: 2.142889976501465
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 446901 spectral peaks found.
# Elapsed time: 2.3331472873687744
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 439431 spectral peaks found.
# Elapsed time: 2.1878697872161865
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 418804 spectral peaks found.
# Elapsed time: 2.3975789546966553
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 137212 spectral peaks found.
# Elapsed time: 1.7631824016571045
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A06_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6045951843261719
#
# ### Working on A07... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 415972 spectral peaks found.
# Elapsed time: 2.2044694423675537
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 530802 spectral peaks found.
# Elapsed time: 2.3244011402130127
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455968 spectral peaks found.
# Elapsed time: 2.227145195007324
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 456787 spectral peaks found.
# Elapsed time: 2.113882303237915
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 468619 spectral peaks found.
# Elapsed time: 2.246720314025879
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 433654 spectral peaks found.
# Elapsed time: 2.3212907314300537
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 430148 spectral peaks found.
# Elapsed time: 2.1471002101898193
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 443404 spectral peaks found.
# Elapsed time: 2.279562473297119
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 469495 spectral peaks found.
# Elapsed time: 2.123358964920044
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 472127 spectral peaks found.
# Elapsed time: 2.1373722553253174
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 498664 spectral peaks found.
# Elapsed time: 2.2979750633239746
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 485453 spectral peaks found.
# Elapsed time: 2.372419834136963
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 501922 spectral peaks found.
# Elapsed time: 2.3997087478637695
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 507374 spectral peaks found.
# Elapsed time: 2.3915629386901855
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 506819 spectral peaks found.
# Elapsed time: 2.1593286991119385
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 494464 spectral peaks found.
# Elapsed time: 2.4052975177764893
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461842 spectral peaks found.
# Elapsed time: 2.126310348510742
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455625 spectral peaks found.
# Elapsed time: 2.311217784881592
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 459908 spectral peaks found.
# Elapsed time: 2.123797655105591
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 458993 spectral peaks found.
# Elapsed time: 2.3964388370513916
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 448922 spectral peaks found.
# Elapsed time: 2.2149908542633057
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 429888 spectral peaks found.
# Elapsed time: 2.4887025356292725
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 175031 spectral peaks found.
# Elapsed time: 1.86411714553833
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A07_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.7168998718261719
#
# ### Working on A08... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 417008 spectral peaks found.
# Elapsed time: 2.1987802982330322
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 507475 spectral peaks found.
# Elapsed time: 2.3638548851013184
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 432172 spectral peaks found.
# Elapsed time: 2.245727300643921
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445103 spectral peaks found.
# Elapsed time: 2.1202552318573
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 469202 spectral peaks found.
# Elapsed time: 2.258875846862793
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 401225 spectral peaks found.
# Elapsed time: 2.3260319232940674
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 402851 spectral peaks found.
# Elapsed time: 2.1043953895568848
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 429416 spectral peaks found.
# Elapsed time: 2.2285962104797363
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 454780 spectral peaks found.
# Elapsed time: 2.176739454269409
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 462762 spectral peaks found.
# Elapsed time: 2.1760265827178955
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 486156 spectral peaks found.
# Elapsed time: 2.271009922027588
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470134 spectral peaks found.
# Elapsed time: 2.3360021114349365
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 482770 spectral peaks found.
# Elapsed time: 2.4377522468566895
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488969 spectral peaks found.
# Elapsed time: 2.416994094848633
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 484199 spectral peaks found.
# Elapsed time: 2.1768391132354736
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 482817 spectral peaks found.
# Elapsed time: 2.2825124263763428
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 437103 spectral peaks found.
# Elapsed time: 2.244915246963501
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 419334 spectral peaks found.
# Elapsed time: 2.4084925651550293
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 430764 spectral peaks found.
# Elapsed time: 2.1543304920196533
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 451248 spectral peaks found.
# Elapsed time: 2.3132498264312744
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 439518 spectral peaks found.
# Elapsed time: 2.2105581760406494
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 420329 spectral peaks found.
# Elapsed time: 2.3206980228424072
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 167971 spectral peaks found.
# Elapsed time: 1.8655951023101807
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A08_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6502060890197754
#
# ### Working on A09... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 402037 spectral peaks found.
# Elapsed time: 2.275874614715576
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 496121 spectral peaks found.
# Elapsed time: 2.2938976287841797
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 428705 spectral peaks found.
# Elapsed time: 2.256615161895752
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 477159 spectral peaks found.
# Elapsed time: 2.1025352478027344
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 484888 spectral peaks found.
# Elapsed time: 2.3232526779174805
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 415685 spectral peaks found.
# Elapsed time: 2.25905704498291
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 409894 spectral peaks found.
# Elapsed time: 2.147860527038574
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445053 spectral peaks found.
# Elapsed time: 2.3141143321990967
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 481308 spectral peaks found.
# Elapsed time: 2.205670118331909
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 478947 spectral peaks found.
# Elapsed time: 2.170788049697876
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517573 spectral peaks found.
# Elapsed time: 2.2393062114715576
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 513865 spectral peaks found.
# Elapsed time: 2.3852713108062744
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 497105 spectral peaks found.
# Elapsed time: 2.363778591156006
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 501541 spectral peaks found.
# Elapsed time: 2.3603134155273438
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 549680 spectral peaks found.
# Elapsed time: 2.14560604095459
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 491228 spectral peaks found.
# Elapsed time: 2.3436636924743652
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 533110 spectral peaks found.
# Elapsed time: 2.2698869705200195
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 590830 spectral peaks found.
# Elapsed time: 2.4185376167297363
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 589437 spectral peaks found.
# Elapsed time: 2.3618814945220947
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 652909 spectral peaks found.
# Elapsed time: 2.4712607860565186
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 644304 spectral peaks found.
# Elapsed time: 2.3684916496276855
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 631289 spectral peaks found.
# Elapsed time: 2.4375064373016357
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 226672 spectral peaks found.
# Elapsed time: 1.8511297702789307
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A09_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6982312202453613
#
# ### Working on A10... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 401296 spectral peaks found.
# Elapsed time: 2.2429022789001465
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488926 spectral peaks found.
# Elapsed time: 2.268751621246338
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 480255 spectral peaks found.
# Elapsed time: 2.3011021614074707
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 493015 spectral peaks found.
# Elapsed time: 2.1198160648345947
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 496911 spectral peaks found.
# Elapsed time: 2.3616678714752197
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 444564 spectral peaks found.
# Elapsed time: 2.41353440284729
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 434616 spectral peaks found.
# Elapsed time: 2.171204090118408
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470827 spectral peaks found.
# Elapsed time: 2.2758870124816895
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488053 spectral peaks found.
# Elapsed time: 2.242072343826294
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 491316 spectral peaks found.
# Elapsed time: 2.167365312576294
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520205 spectral peaks found.
# Elapsed time: 2.398491859436035
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 486786 spectral peaks found.
# Elapsed time: 2.3353333473205566
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 513296 spectral peaks found.
# Elapsed time: 2.3523786067962646
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 505017 spectral peaks found.
# Elapsed time: 2.399533271789551
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 515798 spectral peaks found.
# Elapsed time: 2.22924542427063
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 509093 spectral peaks found.
# Elapsed time: 2.4221625328063965
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 467829 spectral peaks found.
# Elapsed time: 2.210099458694458
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445597 spectral peaks found.
# Elapsed time: 2.348492383956909
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 462215 spectral peaks found.
# Elapsed time: 2.260727643966675
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 479619 spectral peaks found.
# Elapsed time: 2.425417184829712
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470414 spectral peaks found.
# Elapsed time: 2.2103431224823
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 446450 spectral peaks found.
# Elapsed time: 2.4219682216644287
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 193875 spectral peaks found.
# Elapsed time: 1.8048090934753418
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A10_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6749498844146729
#
# ### Working on A11... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 403627 spectral peaks found.
# Elapsed time: 2.25431489944458
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517178 spectral peaks found.
# Elapsed time: 2.2645862102508545
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 458085 spectral peaks found.
# Elapsed time: 2.2700562477111816
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450189 spectral peaks found.
# Elapsed time: 2.1557257175445557
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 464237 spectral peaks found.
# ...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461426 spectral peaks found.
# Elapsed time: 2.203848361968994
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 479538 spectral peaks found.
# Elapsed time: 2.44834303855896
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 472543 spectral peaks found.
# Elapsed time: 2.2045106887817383
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 444015 spectral peaks found.
# Elapsed time: 2.318983793258667
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 452882 spectral peaks found.
# Elapsed time: 2.21907114982605
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 254525 spectral peaks found.
# Elapsed time: 2.0843472480773926
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B17_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.7615277767181396
#
# ### Working on B18... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 514989 spectral peaks found.
# Elapsed time: 2.175715923309326
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 941051 spectral peaks found.
# Elapsed time: 2.4081311225891113
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 863618 spectral peaks found.
# Elapsed time: 2.388322114944458
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 709621 spectral peaks found.
# Elapsed time: 2.2243058681488037
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 769360 spectral peaks found.
# Elapsed time: 2.40732479095459
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 816372 spectral peaks found.
# Elapsed time: 2.4618024826049805
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 772804 spectral peaks found.
# Elapsed time: 2.328176975250244
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 739058 spectral peaks found.
# Elapsed time: 2.4861323833465576
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 726823 spectral peaks found.
# Elapsed time: 2.240854501724243
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 741434 spectral peaks found.
# Elapsed time: 2.2374844551086426
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 758166 spectral peaks found.
# Elapsed time: 2.4879345893859863
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 754395 spectral peaks found.
# Elapsed time: 2.3715078830718994
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 764375 spectral peaks found.
# Elapsed time: 2.4864747524261475
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 780954 spectral peaks found.
# Elapsed time: 2.4411730766296387
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 763295 spectral peaks found.
# Elapsed time: 2.3590075969696045
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 775157 spectral peaks found.
# Elapsed time: 2.4337334632873535
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 745133 spectral peaks found.
# Elapsed time: 2.3667211532592773
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 786066 spectral peaks found.
# Elapsed time: 2.381659984588623
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 774667 spectral peaks found.
# Elapsed time: 2.251312017440796
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 729832 spectral peaks found.
# Elapsed time: 2.5278799533843994
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 692299 spectral peaks found.
# Elapsed time: 2.3260369300842285
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 640498 spectral peaks found.
# Elapsed time: 2.478435754776001
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 610467 spectral peaks found.
# Elapsed time: 2.2908759117126465
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 339562 spectral peaks found.
# Elapsed time: 2.080996036529541
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B18_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 1.2434346675872803
#
# ### Working on B19... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 344533 spectral peaks found.
# Elapsed time: 2.1465001106262207
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 645540 spectral peaks found.
# Elapsed time: 2.3130767345428467
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 576341 spectral peaks found.
# Elapsed time: 2.341369390487671
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 495813 spectral peaks found.
# Elapsed time: 2.0884313583374023
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 529302 spectral peaks found.
# Elapsed time: 2.292512893676758
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 585814 spectral peaks found.
# Elapsed time: 2.42526912689209
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 573423 spectral peaks found.
# Elapsed time: 2.1694796085357666
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 550748 spectral peaks found.
# Elapsed time: 2.3763766288757324
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 533356 spectral peaks found.
# Elapsed time: 2.222888708114624
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 534250 spectral peaks found.
# Elapsed time: 2.2042124271392822
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 563159 spectral peaks found.
# Elapsed time: 2.4694197177886963
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 573824 spectral peaks found.
# Elapsed time: 2.4002649784088135
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 569674 spectral peaks found.
# Elapsed time: 2.3446145057678223
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 586488 spectral peaks found.
# Elapsed time: 2.3320541381835938
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 565275 spectral peaks found.
# Elapsed time: 2.2636146545410156
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 598934 spectral peaks found.
# Elapsed time: 2.4742000102996826
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 582007 spectral peaks found.
# Elapsed time: 2.1937155723571777
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 592550 spectral peaks found.
# Elapsed time: 2.5401737689971924
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 594787 spectral peaks found.
# Elapsed time: 2.22163462638855
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 548501 spectral peaks found.
# Elapsed time: 2.421771287918091
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 515421 spectral peaks found.
# Elapsed time: 2.2697341442108154
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 523309 spectral peaks found.
# Elapsed time: 2.3360531330108643
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 559759 spectral peaks found.
# Elapsed time: 2.336291790008545
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 218109 spectral peaks found.
# Elapsed time: 2.214975595474243
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B19_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.8229260444641113
#
# ### Working on B20... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 282495 spectral peaks found.
# Elapsed time: 2.068138837814331
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520987 spectral peaks found.
# Elapsed time: 2.3188986778259277
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 460816 spectral peaks found.
# Elapsed time: 2.2872722148895264
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 499849 spectral peaks found.
# Elapsed time: 2.105942964553833
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520640 spectral peaks found.
# Elapsed time: 2.3095884323120117
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455171 spectral peaks found.
# Elapsed time: 2.261084794998169
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470169 spectral peaks found.
# Elapsed time: 2.0774505138397217
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 490013 spectral peaks found.
# Elapsed time: 2.3198776245117188
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 498332 spectral peaks found.
# Elapsed time: 2.160825490951538
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 503526 spectral peaks found.
# Elapsed time: 2.1305625438690186
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 522268 spectral peaks found.
# Elapsed time: 2.385434150695801
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 505900 spectral peaks found.
# Elapsed time: 2.3859715461730957
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 504495 spectral peaks found.
# Elapsed time: 2.3724820613861084
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 528965 spectral peaks found.
# Elapsed time: 2.433990240097046
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517458 spectral peaks found.
# Elapsed time: 2.209643602371216
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 528571 spectral peaks found.
# Elapsed time: 2.445242404937744
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461517 spectral peaks found.
# Elapsed time: 2.2389144897460938
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 463918 spectral peaks found.
# Elapsed time: 2.408115863800049
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 478301 spectral peaks found.
# Elapsed time: 2.3404879570007324
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488562 spectral peaks found.
# Elapsed time: 2.4547619819641113
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 485603 spectral peaks found.
# Elapsed time: 2.1590073108673096
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 467153 spectral peaks found.
# Elapsed time: 2.312753677368164
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 466733 spectral peaks found.
# Elapsed time: 2.236927032470703
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 205679 spectral peaks found.
# Elapsed time: 1.9933655261993408
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B20_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.7285525798797607
