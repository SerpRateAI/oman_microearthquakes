# %% [markdown]
# # Find spectral peaks in geophone spectrograms

# %%
# Imports
from os.path import join
from pandas import concat
from time import time
from multiprocessing import Pool

from utils_basic import SPECTROGRAM_DIR as indir, GEO_STATIONS as stations
from utils_spec import assemble_spec_filename, find_geo_station_spectral_peaks, read_geo_spectrograms, read_geo_spec_headers, save_spectral_peaks
from utils_plot import plot_geo_total_psd_and_peaks, save_figure

# %%
# Inputs
# Data
window_length = 1.0
overlap = 0.0
downsample = False
downsample_factor = 60

# Finding peaks
num_process = 32
rbw_threshold = 0.2
prom_threshold = 10
freqmin = None
freqmax = 200.0

# Writing
to_csv = False
to_hdf = True

# %%
# Loop over days and stations
outdir = indir
for station in stations:
    print(f"### Working on {station}... ###")

    # The DataFrame for storing the peak detections for the stations
    peak_dfs = []

    # Read the list of time labels
    print("Reading the list of time labels...")
    if downsample:
        filename_in = assemble_spec_filename("whole_deployment", "daily", "geo", station, window_length, overlap, downsample, downsample_factor = downsample_factor)
        inpath = join(indir, filename_in)
    else:
        filename_in = assemble_spec_filename("whole_deployment", "daily", "geo", station, window_length, overlap, downsample)
        inpath = join(indir, filename_in)

    header_dict = read_geo_spec_headers(inpath)
    time_labels = header_dict["time_labels"]

    # Process each time label
    for time_label in time_labels:
        clock1 = time()
        # Read the spectrograms
        print(f"Reading the spectrograms of {time_label}...")
        stream_spec = read_geo_spectrograms(inpath, time_labels = [time_label])

        # Find the peaks
        print("Detecting the peaks...")
        peak_df, _ = find_geo_station_spectral_peaks(stream_spec, num_process, rbw_threshold = rbw_threshold, prom_threshold = prom_threshold, freqmin = freqmin, freqmax = freqmax)
        print(f"In total, {len(peak_df)} spectral peaks found.")

        # Add the station to the dataframe
        peak_df["station"] = station

        # Append to the list
        peak_dfs.append(peak_df)

        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")

    # Save the results
    print("Saving the results...")
    peak_df = concat(peak_dfs)
    peak_df.drop_duplicates(subset = ["station", "time", "frequency"], inplace = True)
    peak_df.reset_index(drop = True, inplace = True)

    if downsample:
        file_stem = f"geo_spectral_peaks_{station}_window{window_length:.0f}s_overlap{overlap:.1f}_downsample{downsample_factor:d}_prom{prom_threshold:.0f}db_rbw{rbw_threshold:.1f}"
    else:
        file_stem = f"geo_spectral_peaks_{station}_window{window_length:.0f}s_overlap{overlap:.1f}_prom{prom_threshold:.0f}db_rbw{rbw_threshold:.1f}"

    if to_csv:
        print("Saving the CSV file...")
        clock1 = time()

        save_spectral_peaks(peak_df, file_stem, "csv")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")

    
    if to_hdf:
        print("Saving the HDF file...")
        clock1 = time()
    
        save_spectral_peaks(peak_df, file_stem, "hdf")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")
# Out:
# ### Working on A01... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 351880 spectral peaks found.
# Elapsed time: 1.8440020084381104
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 510519 spectral peaks found.
# Elapsed time: 2.327942371368408
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422596 spectral peaks found.
# Elapsed time: 2.334475040435791
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 451023 spectral peaks found.
# Elapsed time: 2.3024518489837646
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 457930 spectral peaks found.
# Elapsed time: 2.402585506439209
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422246 spectral peaks found.
# Elapsed time: 2.48994779586792
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 414140 spectral peaks found.
# Elapsed time: 2.27237606048584
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 431532 spectral peaks found.
# Elapsed time: 2.4875855445861816
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450604 spectral peaks found.
# Elapsed time: 2.441728115081787
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455354 spectral peaks found.
# Elapsed time: 2.4303982257843018
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total,
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470827 spectral peaks found.
# Elapsed time: 2.674787998199463
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488053 spectral peaks found.
# Elapsed time: 2.6523549556732178
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 491316 spectral peaks found.
# Elapsed time: 2.8636369705200195
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520205 spectral peaks found.
# Elapsed time: 2.8698766231536865
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 486786 spectral peaks found.
# Elapsed time: 2.947697162628174
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 513296 spectral peaks found.
# Elapsed time: 2.913227081298828
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 505017 spectral peaks found.
# Elapsed time: 2.957681655883789
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 515798 spectral peaks found.
# Elapsed time: 2.8173511028289795
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 509093 spectral peaks found.
# Elapsed time: 2.7896149158477783
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 467829 spectral peaks found.
# Elapsed time: 2.954498767852783
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445597 spectral peaks found.
# Elapsed time: 2.911555528640747
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 462215 spectral peaks found.
# Elapsed time: 2.7170257568359375
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 479619 spectral peaks found.
# Elapsed time: 2.8509862422943115
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470414 spectral peaks found.
# Elapsed time: 2.6172988414764404
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 446450 spectral peaks found.
# Elapsed time: 3.1089441776275635
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 193844 spectral peaks found.
# Elapsed time: 1.8905861377716064
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A10_window1s_overlap0.0_prom10db_rbw0.2.h5
# Elapsed time: 0.571122407913208
#
# ### Working on A11... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 403573 spectral peaks found.
# Elapsed time: 2.519521951675415
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517178 spectral peaks found.
# Elapsed time: 2.894442081451416
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 458085 spectral peaks found.
# Elapsed time: 2.9332973957061768
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450189 spectral peaks found.
# Elapsed time: 2.603729486465454
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 464237 spectral peaks found.
# Elapsed time: 2.7612802982330322
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# ...
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461426 spectral peaks found.
# Elapsed time: 2.7165067195892334
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 479538 spectral peaks found.
# Elapsed time: 2.8711605072021484
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 472543 spectral peaks found.
# Elapsed time: 2.752647876739502
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 444015 spectral peaks found.
# Elapsed time: 2.9522347450256348
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 452882 spectral peaks found.
# Elapsed time: 2.758763074874878
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 254371 spectral peaks found.
# Elapsed time: 2.155987024307251
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B17_window1s_overlap0.0_prom10db_rbw0.2.h5
# Elapsed time: 0.6191718578338623
#
# ### Working on B18... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 514927 spectral peaks found.
# Elapsed time: 2.2408382892608643
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 941051 spectral peaks found.
# Elapsed time: 3.056442975997925
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 863618 spectral peaks found.
# Elapsed time: 3.0879955291748047
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 709621 spectral peaks found.
# Elapsed time: 2.7645740509033203
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 769360 spectral peaks found.
# Elapsed time: 2.9537367820739746
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 816372 spectral peaks found.
# Elapsed time: 3.0839664936065674
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 772804 spectral peaks found.
# Elapsed time: 2.818570375442505
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 739058 spectral peaks found.
# Elapsed time: 3.0211288928985596
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 726823 spectral peaks found.
# Elapsed time: 2.7627949714660645
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 741434 spectral peaks found.
# Elapsed time: 3.020958662033081
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 758166 spectral peaks found.
# Elapsed time: 3.046934127807617
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 754395 spectral peaks found.
# Elapsed time: 3.1520841121673584
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 764375 spectral peaks found.
# Elapsed time: 2.903719186782837
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 780954 spectral peaks found.
# Elapsed time: 3.1149094104766846
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 763295 spectral peaks found.
# Elapsed time: 2.827112913131714
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 775157 spectral peaks found.
# Elapsed time: 2.959134340286255
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 745133 spectral peaks found.
# Elapsed time: 2.9777095317840576
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 786066 spectral peaks found.
# Elapsed time: 2.8894898891448975
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 774667 spectral peaks found.
# Elapsed time: 2.7965619564056396
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 729832 spectral peaks found.
# Elapsed time: 2.94337797164917
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 692299 spectral peaks found.
# Elapsed time: 2.8064968585968018
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 640498 spectral peaks found.
# Elapsed time: 3.1003522872924805
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 610467 spectral peaks found.
# Elapsed time: 2.7485454082489014
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 339425 spectral peaks found.
# Elapsed time: 2.26839542388916
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B18_window1s_overlap0.0_prom10db_rbw0.2.h5
# Elapsed time: 0.9816324710845947
#
# ### Working on B19... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 344546 spectral peaks found.
# Elapsed time: 2.1698594093322754
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 645540 spectral peaks found.
# Elapsed time: 3.0257487297058105
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 576341 spectral peaks found.
# Elapsed time: 2.8489818572998047
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 495813 spectral peaks found.
# Elapsed time: 2.733902931213379
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 529302 spectral peaks found.
# Elapsed time: 2.9057559967041016
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 585814 spectral peaks found.
# Elapsed time: 3.063502073287964
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 573423 spectral peaks found.
# Elapsed time: 2.8502628803253174
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 550748 spectral peaks found.
# Elapsed time: 2.9718966484069824
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 533356 spectral peaks found.
# Elapsed time: 2.863799571990967
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 534250 spectral peaks found.
# Elapsed time: 2.864144802093506
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 563159 spectral peaks found.
# Elapsed time: 3.029231071472168
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 573824 spectral peaks found.
# Elapsed time: 3.1148290634155273
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 569674 spectral peaks found.
# Elapsed time: 3.118232488632202
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 586488 spectral peaks found.
# Elapsed time: 3.0212013721466064
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 565275 spectral peaks found.
# Elapsed time: 2.8180222511291504
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 598934 spectral peaks found.
# Elapsed time: 2.967568874359131
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 582007 spectral peaks found.
# Elapsed time: 2.967867612838745
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 592550 spectral peaks found.
# Elapsed time: 2.787696599960327
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 594787 spectral peaks found.
# Elapsed time: 2.721611976623535
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 548501 spectral peaks found.
# Elapsed time: 2.938730478286743
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 515421 spectral peaks found.
# Elapsed time: 2.8607356548309326
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 523309 spectral peaks found.
# Elapsed time: 2.935340642929077
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 559759 spectral peaks found.
# Elapsed time: 3.0235939025878906
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 218047 spectral peaks found.
# Elapsed time: 2.0083866119384766
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B19_window1s_overlap0.0_prom10db_rbw0.2.h5
# Elapsed time: 0.8561692237854004
#
# ### Working on B20... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 282319 spectral peaks found.
# Elapsed time: 2.1901681423187256
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520987 spectral peaks found.
# Elapsed time: 2.981379270553589
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 460816 spectral peaks found.
# Elapsed time: 2.9185092449188232
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 499849 spectral peaks found.
# Elapsed time: 2.7409555912017822
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520640 spectral peaks found.
# Elapsed time: 2.953735589981079
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455171 spectral peaks found.
# Elapsed time: 3.1148841381073
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470169 spectral peaks found.
# Elapsed time: 2.577176570892334
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 490013 spectral peaks found.
# Elapsed time: 2.855621576309204
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 498332 spectral peaks found.
# Elapsed time: 2.937497138977051
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 503526 spectral peaks found.
# Elapsed time: 2.880946159362793
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 522268 spectral peaks found.
# Elapsed time: 2.919635057449341
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 505900 spectral peaks found.
# Elapsed time: 3.133511543273926
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 504495 spectral peaks found.
# Elapsed time: 3.066330671310425
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 528965 spectral peaks found.
# Elapsed time: 2.948059320449829
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517458 spectral peaks found.
# Elapsed time: 2.815260171890259
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 528571 spectral peaks found.
# Elapsed time: 2.917344808578491
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461517 spectral peaks found.
# Elapsed time: 2.7607529163360596
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 463918 spectral peaks found.
# Elapsed time: 2.990098237991333
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 478301 spectral peaks found.
# Elapsed time: 2.817301034927368
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488562 spectral peaks found.
# Elapsed time: 2.862130641937256
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 485603 spectral peaks found.
# Elapsed time: 2.673710346221924
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 467153 spectral peaks found.
# Elapsed time: 2.9790589809417725
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 466733 spectral peaks found.
# Elapsed time: 2.61423659324646
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 205530 spectral peaks found.
# Elapsed time: 2.005232572555542
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B20_window1s_overlap0.0_prom10db_rbw0.2.h5
# Elapsed time: 0.6440894603729248

# %%
1512081 / 3600 / 24
# Out:
# 17.5009375
