# %% [markdown]
# # Find spectral peaks in geophone spectrograms

# %%
# Imports
from os.path import join
from pandas import concat
from time import time
from multiprocessing import Pool

from utils_basic import SPECTROGRAM_DIR as indir, GEO_STATIONS as stations
from utils_spec import assemble_spec_filename, find_geo_station_spectral_peaks, read_geo_spectrograms, read_geo_spec_headers, save_spectral_peaks
from utils_plot import plot_geo_total_psd_and_peaks, save_figure

# %%
# Inputs
# Data
window_length = 1.0
overlap = 0.0
downsample = False
downsample_factor = 60

# Finding peaks
num_process = 32
rbw_threshold = 0.2
prom_threshold = 5
freqmin = None
freqmax = 200.0

# Writing
to_csv = False
to_hdf = True

# %%
# Loop over days and stations
outdir = indir
for station in stations:
    print(f"### Working on {station}... ###")

    # The DataFrame for storing the peak detections for the stations
    peak_dfs = []

    # Read the list of time labels
    print("Reading the list of time labels...")
    if downsample:
        filename_in = assemble_spec_filename("whole_deployment", "daily", "geo", station, window_length, overlap, downsample, downsample_factor = downsample_factor)
        inpath = join(indir, filename_in)
    else:
        filename_in = assemble_spec_filename("whole_deployment", "daily", "geo", station, window_length, overlap, downsample)
        inpath = join(indir, filename_in)

    header_dict = read_geo_spec_headers(inpath)
    time_labels = header_dict["time_labels"]

    # Process each time label
    for time_label in time_labels:
        clock1 = time()
        # Read the spectrograms
        print(f"Reading the spectrograms of {time_label}...")
        stream_spec = read_geo_spectrograms(inpath, time_labels = [time_label])

        # Find the peaks
        print("Detecting the peaks...")
        peak_df, _ = find_geo_station_spectral_peaks(stream_spec, num_process, rbw_threshold = rbw_threshold, prom_threshold = prom_threshold, freqmin = freqmin, freqmax = freqmax)
        print(f"In total, {len(peak_df)} spectral peaks found.")

        # Add the station to the dataframe
        peak_df["station"] = station

        # Append to the list
        peak_dfs.append(peak_df)

        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")

    # Save the results
    print("Saving the results...")
    peak_df = concat(peak_dfs)
    peak_df.drop_duplicates(subset = ["station", "time", "frequency"], inplace = True)
    peak_df.reset_index(drop = True, inplace = True)

    if downsample:
        file_stem = f"geo_spectral_peaks_{station}_window{window_length:.0f}s_overlap{overlap:.1f}_downsample{downsample_factor:d}_prom{prom_threshold:.0f}db_rbw{rbw_threshold:.1f}"
    else:
        file_stem = f"geo_spectral_peaks_{station}_window{window_length:.0f}s_overlap{overlap:.1f}_prom{prom_threshold:.0f}db_rbw{rbw_threshold:.1f}"

    if to_csv:
        print("Saving the CSV file...")
        clock1 = time()

        save_spectral_peaks(peak_df, file_stem, "csv")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")

    
    if to_hdf:
        print("Saving the HDF file...")
        clock1 = time()
    
        save_spectral_peaks(peak_df, file_stem, "hdf")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")
# Out:
# ### Working on A01... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1123419 spectral peaks found.
# Elapsed time: 1.5335769653320312
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1646887 spectral peaks found.
# Elapsed time: 2.2065412998199463
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1512081 spectral peaks found.
# Elapsed time: 2.223518133163452
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1524296 spectral peaks found.
# Elapsed time: 2.0652568340301514
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1702426 spectral peaks found.
# Elapsed time: 2.6849584579467773
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1704789 spectral peaks found.
# Elapsed time: 2.309872627258301
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1641937 spectral peaks found.
# Elapsed time: 2.4307754039764404
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1597649 spectral peaks found.
# Elapsed time: 2.4628279209136963
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1602197 spectral peaks found.
# Elapsed time: 2.60152006149292
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1653209 spectral peaks found.
# Elapsed time: 2.3354108333587646
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 649549 spectral peaks found.
# Elapsed time: 1.4852869510650635
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B19_window1s_overlap0.0_prom5db_rbw0.2.h5
# Elapsed time: 2.304872512817383
#
# ### Working on B20... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 861059 spectral peaks found.
# Elapsed time: 1.6813733577728271
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1626166 spectral peaks found.
# Elapsed time: 2.4521923065185547
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1523883 spectral peaks found.
# Elapsed time: 2.5409419536590576
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1545762 spectral peaks found.
# Elapsed time: 2.2189416885375977
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1566510 spectral peaks found.
# Elapsed time: 2.406507968902588
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1510814 spectral peaks found.
# Elapsed time: 2.351872205734253
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1518592 spectral peaks found.
# Elapsed time: 2.2094907760620117
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1558768 spectral peaks found.
# Elapsed time: 2.447892904281616
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1572356 spectral peaks found.
# Elapsed time: 2.2688817977905273
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1580602 spectral peaks found.
# Elapsed time: 2.5722479820251465
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1613870 spectral peaks found.
# Elapsed time: 2.5162413120269775
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1594877 spectral peaks found.
# Elapsed time: 2.564997911453247
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1610705 spectral peaks found.
# Elapsed time: 2.502639055252075
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1616944 spectral peaks found.
# Elapsed time: 2.5277793407440186
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1622107 spectral peaks found.
# Elapsed time: 2.3290750980377197
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1620868 spectral peaks found.
# Elapsed time: 2.637763738632202
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1546163 spectral peaks found.
# Elapsed time: 2.3356876373291016
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1537647 spectral peaks found.
# Elapsed time: 2.6820180416107178
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1559113 spectral peaks found.
# Elapsed time: 2.49438738822937
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1583182 spectral peaks found.
# Elapsed time: 2.614525318145752
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1554322 spectral peaks found.
# Elapsed time: 2.4807605743408203
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1539873 spectral peaks found.
# Elapsed time: 2.5293500423431396
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 1559875 spectral peaks found.
# Elapsed time: 2.542556047439575
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 669460 spectral peaks found.
# Elapsed time: 1.5697898864746094
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B20_window1s_overlap0.0_prom5db_rbw0.2.h5
# Elapsed time: 2.0884816646575928
