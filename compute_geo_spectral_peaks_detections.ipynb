# %% [markdown]
# # Find spectral peaks in geophone spectrograms

# %%
# Imports
from os.path import join
from pandas import concat
from time import time
from multiprocessing import Pool

from utils_basic import SPECTROGRAM_DIR as indir, GEO_STATIONS as stations
from utils_spec import find_geo_station_spectral_peaks, get_spectrogram_file_suffix, get_spec_peak_file_suffix 
from utils_spec import read_geo_spectrograms, read_geo_spec_headers, save_spectral_peaks
from utils_plot import plot_geo_total_psd_and_peaks, save_figure

# %%
# Inputs
# Data
window_length = 1.0
overlap = 0.0
downsample = False
downsample_factor = 60

# Finding peaks
num_process = 32
rbw_threshold = 0.2
prom_threshold = 10
min_freq = None
max_freq = 200.0

# Writing
to_csv = False
to_hdf = True

# %%
# Loop over days and stations
outdir = indir
for station in stations:
    print(f"### Working on {station}... ###")

    # The DataFrame for storing the peak detections for the stations
    peak_dfs = []

    # Read the list of time labels
    print("Reading the list of time labels...")
    suffix_spec = get_spectrogram_file_suffix(window_length, overlap, downsample, downsample_factor = downsample_factor)
    filename_in = f"whole_deployment_daily_geo_spectrograms_{station}_{suffix_spec}.h5"
    inpath = join(indir, filename_in)

    header_dict = read_geo_spec_headers(inpath)
    time_labels = header_dict["time_labels"]

    # Process each time label
    for time_label in time_labels:
        clock1 = time()
        # Read the spectrograms
        print(f"Reading the spectrograms of {time_label}...")
        stream_spec = read_geo_spectrograms(inpath, time_labels = [time_label])

        # Find the peaks
        print("Detecting the peaks...")
        peak_df, _ = find_geo_station_spectral_peaks(stream_spec, num_process, 
                                                     rbw_threshold = rbw_threshold, prom_threshold = prom_threshold, 
                                                     min_freq = min_freq, max_freq = max_freq)
        print(f"In total, {len(peak_df)} spectral peaks found.")

        # Add the station to the dataframe
        peak_df["station"] = station

        # Append to the list
        peak_dfs.append(peak_df)

        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")

    # Save the results
    print("Saving the results...")
    peak_df = concat(peak_dfs)
    peak_df.drop_duplicates(subset = ["station", "time", "frequency"], inplace = True)
    peak_df.reset_index(drop = True, inplace = True)

    suffix_peak = get_spec_peak_file_suffix(prom_threshold, rbw_threshold, min_freq = min_freq, max_freq = max_freq)
    file_stem = f"geo_spectral_peaks_{station}_{suffix_spec}_{suffix_peak}"

    if to_csv:
        print("Saving the CSV file...")
        clock1 = time()

        save_spectral_peaks(peak_df, file_stem, "csv")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")

    
    if to_hdf:
        print("Saving the HDF file...")
        clock1 = time()
    
        save_spectral_peaks(peak_df, file_stem, "hdf")
    
        clock2 = time()
        elapse = clock2 - clock1
        print(f"Elapsed time: {elapse}")    
        print("")
# Out:
# ### Working on A01... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 352003 spectral peaks found.
# Elapsed time: 2.0750253200531006
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 510519 spectral peaks found.
# Elapsed time: 2.0678939819335938
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422596 spectral peaks found.
# Elapsed time: 2.048037052154541
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 451023 spectral peaks found.
# Elapsed time: 1.9535260200500488
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 457930 spectral peaks found.
# Elapsed time: 2.194838762283325
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 422246 spectral peaks found.
# Elapsed time: 2.1464056968688965
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 414140 spectral peaks found.
# Elapsed time: 2.1190385818481445
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 431532 spectral peaks found.
# Elapsed time: 2.4146082401275635
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450604 spectral peaks found.
# Elapsed time: 2.189356803894043
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455354 spectral peaks found.
# Elapsed time: 2.067129373550415
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 476286 spectral peaks found.
# Elapsed time: 2.301968812942505
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 468133 spectral peaks found.
# Elapsed time: 2.450913667678833
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 432172 spectral peaks found.
# Elapsed time: 2.2007946968078613
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445103 spectral peaks found.
# Elapsed time: 1.9955344200134277
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 469202 spectral peaks found.
# Elapsed time: 2.187185764312744
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 401225 spectral peaks found.
# Elapsed time: 2.3333334922790527
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 402851 spectral peaks found.
# Elapsed time: 1.9044666290283203
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 429416 spectral peaks found.
# Elapsed time: 2.271991014480591
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 454780 spectral peaks found.
# Elapsed time: 2.093907594680786
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 462762 spectral peaks found.
# Elapsed time: 2.0557548999786377
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 486156 spectral peaks found.
# Elapsed time: 2.14705228805542
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470134 spectral peaks found.
# Elapsed time: 2.358830451965332
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 482770 spectral peaks found.
# Elapsed time: 2.384225368499756
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488969 spectral peaks found.
# Elapsed time: 2.434082508087158
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 484199 spectral peaks found.
# Elapsed time: 2.065070867538452
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 482817 spectral peaks found.
# Elapsed time: 2.3606374263763428
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 437103 spectral peaks found.
# Elapsed time: 2.1306915283203125
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 419334 spectral peaks found.
# Elapsed time: 2.3727200031280518
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 430764 spectral peaks found.
# Elapsed time: 2.1043760776519775
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 451248 spectral peaks found.
# Elapsed time: 2.2151167392730713
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 439518 spectral peaks found.
# Elapsed time: 2.1137020587921143
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 420329 spectral peaks found.
# Elapsed time: 2.2876222133636475
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 167971 spectral peaks found.
# Elapsed time: 1.6830830574035645
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A08_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.5509891510009766
#
# ### Working on A09... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 402037 spectral peaks found.
# Elapsed time: 2.0689032077789307
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 496121 spectral peaks found.
# Elapsed time: 2.2150321006774902
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 428705 spectral peaks found.
# Elapsed time: 2.1577887535095215
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 477159 spectral peaks found.
# Elapsed time: 2.0299136638641357
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 484888 spectral peaks found.
# Elapsed time: 2.189467191696167
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 415685 spectral peaks found.
# Elapsed time: 2.283022403717041
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 409894 spectral peaks found.
# Elapsed time: 2.0043933391571045
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445053 spectral peaks found.
# Elapsed time: 2.05014705657959
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 481308 spectral peaks found.
# Elapsed time: 2.1112477779388428
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 478947 spectral peaks found.
# Elapsed time: 2.078157901763916
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517573 spectral peaks found.
# Elapsed time: 2.1248130798339844
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 513865 spectral peaks found.
# Elapsed time: 2.3657171726226807
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 497105 spectral peaks found.
# Elapsed time: 2.2100913524627686
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 501541 spectral peaks found.
# Elapsed time: 2.233593225479126
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 549680 spectral peaks found.
# Elapsed time: 2.131065607070923
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 491228 spectral peaks found.
# Elapsed time: 2.32607364654541
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 533110 spectral peaks found.
# Elapsed time: 2.2269551753997803
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 590830 spectral peaks found.
# Elapsed time: 2.3975608348846436
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 589437 spectral peaks found.
# Elapsed time: 2.453212022781372
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 652909 spectral peaks found.
# Elapsed time: 2.408514976501465
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 644304 spectral peaks found.
# Elapsed time: 2.2093260288238525
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 631289 spectral peaks found.
# Elapsed time: 2.4119503498077393
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 226672 spectral peaks found.
# Elapsed time: 2.0394108295440674
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A09_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6552121639251709
#
# ### Working on A10... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 401296 spectral peaks found.
# Elapsed time: 2.359746217727661
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488926 spectral peaks found.
# Elapsed time: 2.7489755153656006
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 480255 spectral peaks found.
# Elapsed time: 2.183444023132324
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 493015 spectral peaks found.
# Elapsed time: 2.0826668739318848
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 496911 spectral peaks found.
# Elapsed time: 2.1653690338134766
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 444564 spectral peaks found.
# Elapsed time: 2.3805794715881348
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 434616 spectral peaks found.
# Elapsed time: 2.0877444744110107
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470827 spectral peaks found.
# Elapsed time: 2.1716244220733643
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488053 spectral peaks found.
# Elapsed time: 2.11590838432312
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 491316 spectral peaks found.
# Elapsed time: 2.139277935028076
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520205 spectral peaks found.
# Elapsed time: 2.1177899837493896
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 486786 spectral peaks found.
# Elapsed time: 2.547882318496704
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 513296 spectral peaks found.
# Elapsed time: 2.372382879257202
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 505017 spectral peaks found.
# Elapsed time: 2.3704161643981934
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 515798 spectral peaks found.
# Elapsed time: 2.1533093452453613
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 509093 spectral peaks found.
# Elapsed time: 2.301553726196289
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 467829 spectral peaks found.
# Elapsed time: 2.181445837020874
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 445597 spectral peaks found.
# Elapsed time: 2.4708476066589355
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 462215 spectral peaks found.
# Elapsed time: 2.1857047080993652
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 479619 spectral peaks found.
# Elapsed time: 2.2918055057525635
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470414 spectral peaks found.
# Elapsed time: 2.073885202407837
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 446450 spectral peaks found.
# Elapsed time: 2.454447031021118
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 193875 spectral peaks found.
# Elapsed time: 1.7415971755981445
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_A10_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.5909812450408936
#
# ### Working on A11... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 403627 spectral peaks found.
# Elapsed time: 2.1180553436279297
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517178 spectral peaks found.
# Elapsed time: 2.4897584915161133
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 458085 spectral peaks found.
# Elapsed time: 2.2175981998443604
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 450189 spectral peaks found.
# Elapsed time: 2.033790349960327
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 464237 spectral peaks found.
# ...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461426 spectral peaks found.
# Elapsed time: 2.0680177211761475
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 479538 spectral peaks found.
# Elapsed time: 2.205404281616211
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 472543 spectral peaks found.
# Elapsed time: 1.9991533756256104
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 444015 spectral peaks found.
# Elapsed time: 2.4063282012939453
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 452882 spectral peaks found.
# Elapsed time: 2.066171169281006
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 254525 spectral peaks found.
# Elapsed time: 1.8863730430603027
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B17_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.6641380786895752
#
# ### Working on B18... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 514989 spectral peaks found.
# Elapsed time: 2.035989284515381
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 941051 spectral peaks found.
# Elapsed time: 2.3607277870178223
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 863618 spectral peaks found.
# Elapsed time: 2.2611286640167236
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 709621 spectral peaks found.
# Elapsed time: 2.019681930541992
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 769360 spectral peaks found.
# Elapsed time: 2.347310781478882
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 816372 spectral peaks found.
# Elapsed time: 2.350637197494507
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 772804 spectral peaks found.
# Elapsed time: 2.0962443351745605
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 739058 spectral peaks found.
# Elapsed time: 2.29512619972229
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 726823 spectral peaks found.
# Elapsed time: 2.0692059993743896
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 741434 spectral peaks found.
# Elapsed time: 2.1045262813568115
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 758166 spectral peaks found.
# Elapsed time: 2.20420503616333
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 754395 spectral peaks found.
# Elapsed time: 2.41927433013916
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 764375 spectral peaks found.
# Elapsed time: 2.3780601024627686
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 780954 spectral peaks found.
# Elapsed time: 2.294356107711792
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 763295 spectral peaks found.
# Elapsed time: 2.1640002727508545
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 775157 spectral peaks found.
# Elapsed time: 2.246063709259033
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 745133 spectral peaks found.
# Elapsed time: 2.221935749053955
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 786066 spectral peaks found.
# Elapsed time: 2.5046565532684326
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 774667 spectral peaks found.
# Elapsed time: 2.2001116275787354
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 729832 spectral peaks found.
# Elapsed time: 2.1946604251861572
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 692299 spectral peaks found.
# Elapsed time: 2.208387613296509
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 640498 spectral peaks found.
# Elapsed time: 2.503634214401245
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 610467 spectral peaks found.
# Elapsed time: 2.1077051162719727
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 339562 spectral peaks found.
# Elapsed time: 1.9289066791534424
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B18_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.8789715766906738
#
# ### Working on B19... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 344533 spectral peaks found.
# Elapsed time: 1.929983139038086
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 645540 spectral peaks found.
# Elapsed time: 2.4051804542541504
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 576341 spectral peaks found.
# Elapsed time: 2.1401517391204834
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 495813 spectral peaks found.
# Elapsed time: 1.9910359382629395
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 529302 spectral peaks found.
# Elapsed time: 2.1694984436035156
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 585814 spectral peaks found.
# Elapsed time: 2.3133058547973633
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 573423 spectral peaks found.
# Elapsed time: 2.001997709274292
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 550748 spectral peaks found.
# Elapsed time: 2.1781649589538574
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 533356 spectral peaks found.
# Elapsed time: 2.089174509048462
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 534250 spectral peaks found.
# Elapsed time: 2.1556448936462402
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 563159 spectral peaks found.
# Elapsed time: 2.184957981109619
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 573824 spectral peaks found.
# Elapsed time: 2.523127794265747
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 569674 spectral peaks found.
# Elapsed time: 2.2491910457611084
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 586488 spectral peaks found.
# Elapsed time: 2.477013111114502
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 565275 spectral peaks found.
# Elapsed time: 2.10152268409729
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 598934 spectral peaks found.
# Elapsed time: 2.362529993057251
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 582007 spectral peaks found.
# Elapsed time: 2.240516424179077
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 592550 spectral peaks found.
# Elapsed time: 2.416834592819214
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 594787 spectral peaks found.
# Elapsed time: 2.078500747680664
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 548501 spectral peaks found.
# Elapsed time: 2.210120439529419
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 515421 spectral peaks found.
# Elapsed time: 2.1174721717834473
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 523309 spectral peaks found.
# Elapsed time: 2.539684295654297
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 559759 spectral peaks found.
# Elapsed time: 2.2119369506835938
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 218109 spectral peaks found.
# Elapsed time: 1.8701860904693604
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B19_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.7483580112457275
#
# ### Working on B20... ###
# Reading the list of time labels...
# Reading the spectrograms of 20200110000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 282495 spectral peaks found.
# Elapsed time: 1.9319679737091064
# Reading the spectrograms of 20200111000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520987 spectral peaks found.
# Elapsed time: 2.409980058670044
# Reading the spectrograms of 20200112000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 460816 spectral peaks found.
# Elapsed time: 2.155378580093384
# Reading the spectrograms of 20200113000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 499849 spectral peaks found.
# Elapsed time: 2.0124621391296387
# Reading the spectrograms of 20200114000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 520640 spectral peaks found.
# Elapsed time: 2.2213852405548096
# Reading the spectrograms of 20200115000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 455171 spectral peaks found.
# Elapsed time: 2.3632848262786865
# Reading the spectrograms of 20200116000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 470169 spectral peaks found.
# Elapsed time: 1.980201244354248
# Reading the spectrograms of 20200117000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 490013 spectral peaks found.
# Elapsed time: 2.109776735305786
# Reading the spectrograms of 20200118000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 498332 spectral peaks found.
# Elapsed time: 2.0453481674194336
# Reading the spectrograms of 20200119000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 503526 spectral peaks found.
# Elapsed time: 2.215210437774658
# Reading the spectrograms of 20200120000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 522268 spectral peaks found.
# Elapsed time: 2.1389429569244385
# Reading the spectrograms of 20200121000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 505900 spectral peaks found.
# Elapsed time: 2.3241024017333984
# Reading the spectrograms of 20200122000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 504495 spectral peaks found.
# Elapsed time: 2.229189157485962
# Reading the spectrograms of 20200123000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 528965 spectral peaks found.
# Elapsed time: 2.1842405796051025
# Reading the spectrograms of 20200124000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 517458 spectral peaks found.
# Elapsed time: 2.0754222869873047
# Reading the spectrograms of 20200125000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 528571 spectral peaks found.
# Elapsed time: 2.1837332248687744
# Reading the spectrograms of 20200126000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 461517 spectral peaks found.
# Elapsed time: 2.0753304958343506
# Reading the spectrograms of 20200127000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 463918 spectral peaks found.
# Elapsed time: 2.329359292984009
# Reading the spectrograms of 20200128000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 478301 spectral peaks found.
# Elapsed time: 2.0311543941497803
# Reading the spectrograms of 20200129000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 488562 spectral peaks found.
# Elapsed time: 2.207195997238159
# Reading the spectrograms of 20200130000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 485603 spectral peaks found.
# Elapsed time: 2.1104676723480225
# Reading the spectrograms of 20200131000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 467153 spectral peaks found.
# Elapsed time: 2.505666494369507
# Reading the spectrograms of 20200201000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 466733 spectral peaks found.
# Elapsed time: 2.100738525390625
# Reading the spectrograms of 20200202000000000000...
# Detecting the peaks...
# Finding the spectral peaks in 32 processes...
# In total, 205679 spectral peaks found.
# Elapsed time: 1.8572890758514404
# Saving the results...
# Saving the HDF file...
# Results saved to /fp/projects01/ec332/data/spectrograms/geo_spectral_peaks_B20_window1s_overlap0.0_prom10db_rbw0.2_freq0to200hz.h5
# Elapsed time: 0.5989720821380615
